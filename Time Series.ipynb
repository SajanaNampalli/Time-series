# %%
import pandas as pd

# %%
df=pd.read_excel("listings.xlsx")

# %%
df
# Out:
#        Stock Symbol                                       Company Name  \
# 0              XXII                            22nd Century Group, Inc
# 1               FAX              Aberdeen Asia-Pacific Income Fund Inc
# 2               IAF                 Aberdeen Australia Equity Fund Inc
# 3                CH                          Aberdeen Chile Fund, Inc.
# 4    ABE             Aberdeen Emerging Markets Smaller Company Oppo...
# ..              ...                                                ...
# 355             WYY                              WidePoint Corporation
# 356             WTT                      Wireless Telecom Group,  Inc.
# 357            XTNT                       Xtant Medical Holdings, Inc.
# 358            YUMA                                  Yuma Energy, Inc.
# 359            ZDGE                                        Zedge, Inc.
#
#      Last Sale  Market Capitalization  IPO Year                 Sector  \
# ...

# %%
df=df.set_index("Stock Symbol")

# %%
df.isna().sum()
# Out:
# Company Name               0
# Last Sale                 14
# Market Capitalization      0
# IPO Year                 255
# Sector                   122
# Industry                 122
# dtype: int64

# %%
df=df.dropna(subset=["Sector"])

# %%
df.shape
# Out:
# (238, 6)

# %%
df.isna().sum()
# Out:
# Company Name               0
# Last Sale                  0
# Market Capitalization      0
# IPO Year                 193
# Sector                     0
# Industry                   0
# dtype: int64

# %%
df
# Out:
#                                 Company Name  Last Sale  \
# Stock Symbol
# XXII                 22nd Century Group, Inc      1.330
# ACU                 Acme United Corporation.     27.390
# AIII             ACRE Realty Investors, Inc.      1.160
# ATNM          Actinium Pharmaceuticals, Inc.      1.470
# AE            Adams Resources & Energy, Inc.     37.800
# ...                                      ...        ...
# WYY                    WidePoint Corporation      0.435
# WTT            Wireless Telecom Group,  Inc.      1.520
# XTNT            Xtant Medical Holdings, Inc.      0.530
# YUMA                       Yuma Energy, Inc.      2.615
# ZDGE                             Zedge, Inc.      3.040
#
#               Market Capitalization  IPO Year                 Sector  \
# Stock Symbol
# XXII                   1.206285e+08       NaN  Consumer Non-Durables
# ACU                    9.113899e+07    1988.0          Capital Goods
# ...

# %%
df=df.dropna()

# %%
df.shape
# Out:
# (45, 6)

# %%
df["Sector"].value_counts()
# Out:
# Health Care              11
# Consumer Services         9
# Basic Industries          8
# Capital Goods             5
# Technology                4
# Public Utilities          3
# Energy                    2
# Finance                   1
# Miscellaneous             1
# Consumer Non-Durables     1
# Name: Sector, dtype: int64

# %%
df
# Out:
#                                            Company Name  Last Sale  \
# Stock Symbol
# ACU                            Acme United Corporation.    27.3900
# AAU                              Almaden Minerals, Ltd.     1.7200
# USAS                        Americas Silver Corporation     3.0500
# AINC                                       Ashford Inc.    57.3373
# AUXO                                      Auxilio, Inc.     6.3043
# BPMX                              BioPharmX Corporation     0.6999
# BRG              Bluerock Residential Growth REIT, Inc.    12.5700
# ROX                                 Castle Brands, Inc.     1.4600
# LEU                                Centrus Energy Corp.     5.8400
# CQH           Cheniere Energy Partners LP Holdings, LLC    24.7700
# CQP                        Cheniere Energy Partners, LP    32.7000
# CIX                            CompX International Inc.    14.3500
# CVRS                   Corindus Vascular Robotics, Inc.     1.1900
# ...

# %%
data=pd.DataFrame({"one":["sandeep","soumya","sajana","sandeep","sajana"],"two":[1,3,1,4,2]})

# %%
data
# Out:
#        one  two
# 0  sandeep    1
# 1   soumya    3
# 2   sajana    1
# 3  sandeep    4
# 4   sajana    2

# %%
data.groupby("one")["two"].nlargest()
# Out:
# one
# sajana   4    2
#          2    1
# sandeep  3    4
#          0    1
# soumya   1    3
# Name: two, dtype: int64

# %%
data.groupby("one")["two"].nlargest(1)
# Out:
# one
# sajana   4    2
# sandeep  3    4
# soumya   1    3
# Name: two, dtype: int64

# %%
df
# Out:
#                                            Company Name  Last Sale  \
# Stock Symbol
# ACU                            Acme United Corporation.    27.3900
# AAU                              Almaden Minerals, Ltd.     1.7200
# USAS                        Americas Silver Corporation     3.0500
# AINC                                       Ashford Inc.    57.3373
# AUXO                                      Auxilio, Inc.     6.3043
# BPMX                              BioPharmX Corporation     0.6999
# BRG              Bluerock Residential Growth REIT, Inc.    12.5700
# ROX                                 Castle Brands, Inc.     1.4600
# LEU                                Centrus Energy Corp.     5.8400
# CQH           Cheniere Energy Partners LP Holdings, LLC    24.7700
# CQP                        Cheniere Energy Partners, LP    32.7000
# CIX                            CompX International Inc.    14.3500
# CVRS                   Corindus Vascular Robotics, Inc.     1.1900
# ...

# %%
a=df.groupby("Sector")["Market Capitalization"].nlargest(1)

# %%
a
# Out:
# Sector                 Stock Symbol
# Basic Industries       SIM             2.123559e+09
# Capital Goods          LBY             3.026988e+08
# Consumer Non-Durables  ROX             2.376444e+08
# Consumer Services      GSAT            1.931551e+09
# Energy                 MPO             4.794015e+08
# Finance                SEB             4.603773e+09
# Health Care            CRHM            6.474389e+08
# Miscellaneous          AUXO            5.913104e+07
# Public Utilities       CQP             1.104692e+10
# Technology             MJCO            1.916146e+08
# Name: Market Capitalization, dtype: float64

# %%
a.index
# Out:
# MultiIndex([(     'Basic Industries',  'SIM'),
#             (        'Capital Goods',  'LBY'),
#             ('Consumer Non-Durables',  'ROX'),
#             (    'Consumer Services', 'GSAT'),
#             (               'Energy',  'MPO'),
#             (              'Finance',  'SEB'),
#             (          'Health Care', 'CRHM'),
#             (        'Miscellaneous', 'AUXO'),
#             (     'Public Utilities',  'CQP'),
#             (           'Technology', 'MJCO')],
#            names=['Sector', 'Stock Symbol'])

# %%
components=a.index.get_level_values("Stock Symbol")

# %%
components
# Out:
# Index(['SIM', 'LBY', 'ROX', 'GSAT', 'MPO', 'SEB', 'CRHM', 'AUXO', 'CQP',
#        'MJCO'],
#       dtype='object', name='Stock Symbol')

# %%
df.loc[components,["Company Name","Last Sale","Market Capitalization"]]
# Out:
#                                    Company Name  Last Sale  \
# Stock Symbol
# SIM                   Grupo Simec, S.A. de C.V.    12.8000
# LBY                                Libbey, Inc.    13.8200
# ROX                         Castle Brands, Inc.     1.4600
# GSAT                           Globalstar, Inc.     1.7300
# MPO           MIDSTATES PETROLEUM COMPANY, INC.    19.1800
# SEB                        Seaboard Corporation  3933.0000
# CRHM                    CRH Medical Corporation     8.9000
# AUXO                              Auxilio, Inc.     6.3043
# CQP                Cheniere Energy Partners, LP    32.7000
# MJCO                                    Majesco     5.2500
#
#               Market Capitalization
# Stock Symbol
# SIM                    2.123559e+09
# LBY                    3.026988e+08
# ROX                    2.376444e+08
# GSAT                   1.931551e+09
# MPO                    4.794015e+08
# SEB                    4.603773e+09
# ...

# %%
df=pd.read_csv("stock_data.csv",parse_dates=["Date"],index_col="Date")

# %%
df
# Out:
#               AAPL    AMGN    AMZN   CPRT     EL      GS    ILMN      MA  \
# Date
# 2010-01-04   30.57   57.72  133.90   4.55  24.27  173.08   30.55   25.68
# 2010-01-05   30.63   57.22  134.69   4.55  24.18  176.14   30.35   25.61
# 2010-01-06   30.14   56.79  132.25   4.53  24.25  174.26   32.22   25.56
# 2010-01-07   30.08   56.27  130.00   4.50  24.56  177.67   32.77   25.39
# 2010-01-08   30.28   56.77  133.52   4.52  24.66  174.31   33.15   25.40
# ...            ...     ...     ...    ...    ...     ...     ...     ...
# 2016-12-23  116.52  147.55  760.59  13.89  78.38  240.97  128.75  104.71
# 2016-12-27  117.26  148.36  771.40  14.00  78.23  241.56  128.94  104.80
# 2016-12-28  116.76  147.67  772.13  13.89  77.22  240.65  127.93  103.68
# 2016-12-29  116.73  147.78  765.15  13.88  77.27  238.18  128.72  103.77
# 2016-12-30  115.82  146.21  749.87  13.85  76.49  239.45  128.04  103.25
#
#               PAA    RIO    TEF     UPS
# Date
# ...

# %%
values=df.div(df.iloc[0])

# %%
values=values.sub(1).mul(100)

# %%
values
# Out:
#                   AAPL        AMGN        AMZN        CPRT          EL  \
# Date
# 2010-01-04    0.000000    0.000000    0.000000    0.000000    0.000000
# 2010-01-05    0.196271   -0.866251    0.589993    0.000000   -0.370828
# 2010-01-06   -1.406608   -1.611227   -1.232263   -0.439560   -0.082406
# 2010-01-07   -1.602879   -2.512128   -2.912621   -1.098901    1.194891
# 2010-01-08   -0.948642   -1.645877   -0.283794   -0.659341    1.606922
# ...                ...         ...         ...         ...         ...
# 2016-12-23  281.157998  155.630631  468.028379  205.274725  222.950144
# 2016-12-27  283.578672  157.033957  476.101568  207.692308  222.332097
# 2016-12-28  281.943081  155.838531  476.646751  205.274725  218.170581
# 2016-12-29  281.844946  156.029106  471.433906  205.054945  218.376597
# 2016-12-30  278.868171  153.309078  460.022405  204.395604  215.162752
#
#                    GS        ILMN          MA        PAA        RIO  \
# Date
# ...

# %%
import matplotlib.pyplot as plt

# %%
values
# Out:
#                   AAPL        AMGN        AMZN        CPRT          EL  \
# Date
# 2010-01-04    0.000000    0.000000    0.000000    0.000000    0.000000
# 2010-01-05    0.196271   -0.866251    0.589993    0.000000   -0.370828
# 2010-01-06   -1.406608   -1.611227   -1.232263   -0.439560   -0.082406
# 2010-01-07   -1.602879   -2.512128   -2.912621   -1.098901    1.194891
# 2010-01-08   -0.948642   -1.645877   -0.283794   -0.659341    1.606922
# ...                ...         ...         ...         ...         ...
# 2016-12-23  281.157998  155.630631  468.028379  205.274725  222.950144
# 2016-12-27  283.578672  157.033957  476.101568  207.692308  222.332097
# 2016-12-28  281.943081  155.838531  476.646751  205.274725  218.170581
# 2016-12-29  281.844946  156.029106  471.433906  205.054945  218.376597
# 2016-12-30  278.868171  153.309078  460.022405  204.395604  215.162752
#
#                    GS        ILMN          MA        PAA        RIO  \
# Date
# ...

# %%
values.iloc[-1].sort_values().plot(kind="barh")
plt.show()

# %%
values
# Out:
#                   AAPL        AMGN        AMZN        CPRT          EL  \
# Date
# 2010-01-04    0.000000    0.000000    0.000000    0.000000    0.000000
# 2010-01-05    0.196271   -0.866251    0.589993    0.000000   -0.370828
# 2010-01-06   -1.406608   -1.611227   -1.232263   -0.439560   -0.082406
# 2010-01-07   -1.602879   -2.512128   -2.912621   -1.098901    1.194891
# 2010-01-08   -0.948642   -1.645877   -0.283794   -0.659341    1.606922
# ...                ...         ...         ...         ...         ...
# 2016-12-23  281.157998  155.630631  468.028379  205.274725  222.950144
# 2016-12-27  283.578672  157.033957  476.101568  207.692308  222.332097
# 2016-12-28  281.943081  155.838531  476.646751  205.274725  218.170581
# 2016-12-29  281.844946  156.029106  471.433906  205.054945  218.376597
# 2016-12-30  278.868171  153.309078  460.022405  204.395604  215.162752
#
#                    GS        ILMN          MA        PAA        RIO  \
# Date
# ...

# %%
dates=pd.read_csv("components (1).csv",index_col=0)

# %%
dates
# Out:
#               Market Capitalization  Last Sale  Number of Shares
# Stock Symbol
# RIO                    70431.476895      38.94       1808.717948
# ILMN                   25409.384000     173.68        146.300000
# CPRT                   13620.922869      29.65        459.390316
# EL                     31122.510011      84.94        366.405816
# AMZN                  422138.530626     884.67        477.170618
# PAA                    22223.001416      30.72        723.404994
# GS                     88840.590477     223.32        397.817439
# AMGN                  118927.210535     161.61        735.890171
# MA                    123330.089602     111.22       1108.884100
# TEF                    54609.806092      10.84       5037.804990
# AAPL                  740024.467000     141.05       5246.540000
# UPS                    90180.886756     103.74        869.297154

# %%
df
# Out:
#               AAPL    AMGN    AMZN   CPRT     EL      GS    ILMN      MA  \
# Date
# 2010-01-04   30.57   57.72  133.90   4.55  24.27  173.08   30.55   25.68
# 2010-01-05   30.63   57.22  134.69   4.55  24.18  176.14   30.35   25.61
# 2010-01-06   30.14   56.79  132.25   4.53  24.25  174.26   32.22   25.56
# 2010-01-07   30.08   56.27  130.00   4.50  24.56  177.67   32.77   25.39
# 2010-01-08   30.28   56.77  133.52   4.52  24.66  174.31   33.15   25.40
# ...            ...     ...     ...    ...    ...     ...     ...     ...
# 2016-12-23  116.52  147.55  760.59  13.89  78.38  240.97  128.75  104.71
# 2016-12-27  117.26  148.36  771.40  14.00  78.23  241.56  128.94  104.80
# 2016-12-28  116.76  147.67  772.13  13.89  77.22  240.65  127.93  103.68
# 2016-12-29  116.73  147.78  765.15  13.88  77.27  238.18  128.72  103.77
# 2016-12-30  115.82  146.21  749.87  13.85  76.49  239.45  128.04  103.25
#
#               PAA    RIO    TEF     UPS
# Date
# ...

# %%
data=df.mul(dates["Number of Shares"])

# %%
data
# Out:
#                    AAPL           AMGN           AMZN         CPRT  \
# Date
# 2010-01-04  160386.7278   42475.580670   63893.145750  2090.225938
# 2010-01-05  160701.5202   42107.635585   64270.110538  2090.225938
# 2010-01-06  158130.7156   41791.202811   63105.814231  2081.038131
# 2010-01-07  157815.9232   41408.539922   62032.180340  2067.256422
# 2010-01-08  158865.2312   41776.485008   63711.820915  2076.444228
# ...                 ...            ...            ...          ...
# 2016-12-23  611326.8408  108580.594731  362931.200345  6380.931489
# 2016-12-27  615209.2804  109176.665770  368089.414725  6431.464424
# 2016-12-28  612586.0104  108668.901552  368437.749276  6380.931489
# 2016-12-29  612428.6142  108749.849470  365107.098363  6376.337586
# 2016-12-30  607654.2628  107594.501902  357815.931320  6362.555877
#
#                       EL            GS       ILMN             MA  \
# Date
# 2010-01-04   8892.669154  68854.242342   4469.465   28476.143688
# ...

# %%
data
# Out:
#                    AAPL           AMGN           AMZN         CPRT  \
# Date
# 2010-01-04  160386.7278   42475.580670   63893.145750  2090.225938
# 2010-01-05  160701.5202   42107.635585   64270.110538  2090.225938
# 2010-01-06  158130.7156   41791.202811   63105.814231  2081.038131
# 2010-01-07  157815.9232   41408.539922   62032.180340  2067.256422
# 2010-01-08  158865.2312   41776.485008   63711.820915  2076.444228
# ...                 ...            ...            ...          ...
# 2016-12-23  611326.8408  108580.594731  362931.200345  6380.931489
# 2016-12-27  615209.2804  109176.665770  368089.414725  6431.464424
# 2016-12-28  612586.0104  108668.901552  368437.749276  6380.931489
# 2016-12-29  612428.6142  108749.849470  365107.098363  6376.337586
# 2016-12-30  607654.2628  107594.501902  357815.931320  6362.555877
#
#                       EL            GS       ILMN             MA  \
# Date
# 2010-01-04   8892.669154  68854.242342   4469.465   28476.143688
# ...

# %%
first=data.iloc[0]

# %%
first
# Out:
# AAPL    160386.727800
# AMGN     42475.580670
# AMZN     63893.145750
# CPRT      2090.225938
# EL        8892.669154
# GS       68854.242342
# ILMN      4469.465000
# MA       28476.143688
# PAA      19531.934838
# RIO     101342.466626
# TEF     143829.332465
# UPS      50575.708420
# Name: 2010-01-04 00:00:00, dtype: float64

# %%
second=data.iloc[-1]

# %%
pd.concat([first,second],axis=1).plot(kind="barh")

# %%
assign=data.sum(axis=1)

# %%
assign
# Out:
# Date
# 2010-01-04    6.948176e+05
# 2010-01-05    6.979957e+05
# 2010-01-06    6.946857e+05
# 2010-01-07    6.912416e+05
# 2010-01-08    6.958476e+05
#                   ...
# 2016-12-23    1.588874e+06
# 2016-12-27    1.599280e+06
# 2016-12-28    1.593635e+06
# 2016-12-29    1.589422e+06
# 2016-12-30    1.574862e+06
# Length: 1762, dtype: float64

# %%
assign.div(assign.iloc[0]).mul(100).plot()
